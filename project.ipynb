# %% [markdown]
# <a href="https://colab.research.google.com/github/chandrasekarmd15-ops/python_demo/blob/main/project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
ab=pd.read_csv("/content/people.xls - people.xls.csv")

# %%
ab
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
ab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfactoryLevel      14999 non-null  float64
#  1   lastEvaluation         14999 non-null  float64
#  2   numberOfProjects       14999 non-null  int64
#  3   avgMonthlyHours        14999 non-null  int64
#  4   timeSpent.company      14999 non-null  int64
#  5   workAccident           14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotionInLast5years  14999 non-null  int64
#  8   dept                   14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
ab.describe()
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# count       14999.000000    14999.000000      14999.000000     14999.000000
# mean            0.612834        0.716102          3.803054       201.050337
# std             0.248631        0.171169          1.232592        49.943099
# min             0.090000        0.360000          2.000000        96.000000
# 25%             0.440000        0.560000          3.000000       156.000000
# 50%             0.640000        0.720000          4.000000       200.000000
# 75%             0.820000        0.870000          5.000000       245.000000
# max             1.000000        1.000000          7.000000       310.000000
#
#        timeSpent.company  workAccident          left  promotionInLast5years
# count       14999.000000  14999.000000  14999.000000           14999.000000
# mean            3.498233      0.144610      0.238083               0.021268
# ...

# %%
ab.isnull().sum()
# Out:
# satisfactoryLevel        0
# lastEvaluation           0
# numberOfProjects         0
# avgMonthlyHours          0
# timeSpent.company        0
# workAccident             0
# left                     0
# promotionInLast5years    0
# dept                     0
# salary                   0
# dtype: int64

# %%
ab.duplicated().sum()
# Out:
# np.int64(3008)

# %%
ab.drop_duplicates(inplace=True)

# %%
ab.duplicated().sum()
# Out:
# np.int64(0)

# %%
ab.head(10)
# Out:
#    satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0               0.38            0.53                 2              157
# 1               0.80            0.86                 5              262
# 2               0.11            0.88                 7              272
# 3               0.37            0.52                 2              159
# 4               0.41            0.50                 2              153
# 5               0.10            0.77                 6              247
# 6               0.92            0.85                 5              259
# 7               0.42            0.53                 2              142
# 8               0.45            0.54                 2              135
# 9               0.11            0.81                 6              305
#
#    timeSpent.company  workAccident  left  promotionInLast5years   dept  salary
# 0                  3             0     1                      0  sales     low
# ...

# %%
ab.tail(20)
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 14968               0.95            0.86                 5              143
# 14972               0.82            0.97                 4              243
# 14973               0.73            0.60                 3              145
# 14975               0.57            1.00                 3              241
# 14976               0.97            0.66                 4              218
# 14977               0.21            0.62                 4              247
# 14978               0.64            0.50                 3              238
# 14980               0.88            0.75                 4              201
# 14981               0.97            0.55                 4              166
# 14982               0.88            0.80                 3              133
# 14983               0.77            0.67                 3              186
# ...

# %%
ab.rename(columns={"lastEvaluation":"performance"}, inplace=True)

# %%
ab
# Out:
#        satisfactoryLevel  performance  numberOfProjects  avgMonthlyHours  \
# 0                   0.38         0.53                 2              157
# 1                   0.80         0.86                 5              262
# 2                   0.11         0.88                 7              272
# 3                   0.37         0.52                 2              159
# 4                   0.41         0.50                 2              153
# ...                  ...          ...               ...              ...
# 14992               0.30         0.88                 5              245
# 14995               0.99         0.83                 4              274
# 14996               0.72         0.72                 4              175
# 14997               0.24         0.91                 5              177
# 14998               0.77         0.83                 6              271
#
#        timeSpent.company  workAccident  left  promotionInLast5years  \
# ...

# %%
col_list=ab.columns

# %%
col_list
# Out:
# Index(['satisfactoryLevel', 'performance', 'numberOfProjects',
#        'avgMonthlyHours', 'timeSpent.company', 'workAccident', 'left',
#        'promotionInLast5years', 'dept', 'salary'],
#       dtype='object')

# %%
ab["salary"].unique()
# Out:
# array(['low', 'medium', 'high'], dtype=object)

# %%
ab["salary"].nunique()
# Out:
# 3

# %%
ab["salary"].value_counts()
# Out:
# salary
# low       5740
# medium    5261
# high       990
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig=sns.countplot(data=ab,x="salary")
fig.bar_label(fig.containers[0])
# Out:
# [Text(0, 0, '5740'), Text(0, 0, '5261'), Text(0, 0, '990')]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig=sns.countplot(data=ab,x="salary",hue="salary")
fig.set_title("Diff Salary")
for container in fig.containers:
    fig.bar_label(container)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig=sns.countplot(data=ab,x="salary",hue="salary",palette=("red","green","yellow"))
fig.set_title("Diff Salary")
for container in fig.containers:
    fig.bar_label(container)

# %%
ab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11991 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfactoryLevel      11991 non-null  float64
#  1   performance            11991 non-null  float64
#  2   numberOfProjects       11991 non-null  int64
#  3   avgMonthlyHours        11991 non-null  int64
#  4   timeSpent.company      11991 non-null  int64
#  5   workAccident           11991 non-null  int64
#  6   left                   11991 non-null  int64
#  7   promotionInLast5years  11991 non-null  int64
#  8   dept                   11991 non-null  object
#  9   salary                 11991 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.0+ MB

# %%
ab["left"].value_counts()
# Out:
# left
# 0    10000
# 1     1991
# Name: count, dtype: int64

# %%
ab["numberOfProjects"].value_counts()
# Out:
# numberOfProjects
# 4    3685
# 3    3520
# 5    2233
# 2    1582
# 6     826
# 7     145
# Name: count, dtype: int64

# %%
ab["left"].value_counts()
# Out:
# left
# 0    10000
# 1     1991
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig=sns.countplot(data=ab,x="numberOfProjects", hue="left")
for container in fig.containers:
    fig.bar_label(container)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 10))
fig=sns.countplot(data=ab,x="dept", hue="left")
fig.set_xticklabels(fig.get_xticklabels(), rotation=90)
for i in fig.containers:
    fig.bar_label(i)
# Out:
# /tmp/ipython-input-2746858291.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig.set_xticklabels(fig.get_xticklabels(), rotation=90)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 10))                         #    fig size changes the size of the bars of x and y axis
fig=sns.countplot(data=ab,x="dept", hue="salary")
plt.xticks(rotation=60)
for i in fig.containers:
    fig.bar_label(i,padding=2)                       # padding changes the distance btween the bar and the bar no.(bar no. is which displays topof each bar)

# %%
# Is promotion effect the emplyee left?
# IS salary have any relation with employee left?

# %%
import pandas as pd
cd=pd.read_csv("/content/Airbnb_datanew.csv")

# %%
cd
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
cd.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
cd.describe().sum()
# Out:
# id                                1.248403e+08
# host_id                           5.666539e+08
# latitude                          4.913937e+04
# longitude                         4.845126e+04
# price                             5.963787e+04
# minimum_nights                    5.018254e+04
# number_of_reviews                 4.962183e+04
# reviews_per_month                 3.890749e+04
# calculated_host_listings_count    4.926710e+04
# availability_365                  4.977640e+04
# dtype: float64

# %%
cd.duplicated().sum()
# Out:
# np.int64(0)

# %%
cd.rename(columns={"id":"listing_id","name":"listing_name","reviews_per_month":"total_reviews","calculated_host_listings_count":"host_listings_count"},inplace=True)

# %%
cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   listing_id           48895 non-null  int64
#  1   listing_name         48879 non-null  object
#  2   host_id              48895 non-null  int64
#  3   host_name            48874 non-null  object
#  4   neighbourhood_group  48895 non-null  object
#  5   neighbourhood        48895 non-null  object
#  6   latitude             48895 non-null  float64
#  7   longitude            48895 non-null  float64
#  8   room_type            48895 non-null  object
#  9   price                48895 non-null  int64
#  10  minimum_nights       48895 non-null  int64
#  11  number_of_reviews    48895 non-null  int64
#  12  last_review          38843 non-null  object
#  13  total_reviews        38843 non-null  float64
#  14  host_listings_count  48895 non-null  int64
# ...

# %%
cd.isnull().sum()     #listing_id,host_id,price,minimum_nights,number_of_reviews,host_listings_count,availability_365
# Out:
# listing_id                 0
# listing_name              16
# host_id                    0
# host_name                 21
# neighbourhood_group        0
# neighbourhood              0
# latitude                   0
# longitude                  0
# room_type                  0
# price                      0
# minimum_nights             0
# number_of_reviews          0
# last_review            10052
# total_reviews          10052
# host_listings_count        0
# availability_365           0
# dtype: int64

# %%
#df.fillna("None", inplace=True)      ----------->>>>>>>>>  to fill all null values

#obj_cols = df.select_dtypes(include='object').columns   ------->>>>>
#df[obj_cols] = df[obj_cols].fillna("None")


#      for single column nly

#df['City'] = df['City'].fillna("None")

# %%
cd['listing_name'] = cd['listing_name'].fillna("No_Name")

# %%
cd['host_name'] = cd['host_name'].fillna("No_Name")

# %%
cd.isnull().sum()
# Out:
# listing_id                 0
# listing_name               0
# host_id                    0
# host_name                  0
# neighbourhood_group        0
# neighbourhood              0
# latitude                   0
# longitude                  0
# room_type                  0
# price                      0
# minimum_nights             0
# number_of_reviews          0
# last_review            10052
# total_reviews          10052
# host_listings_count        0
# availability_365           0
# dtype: int64

# %%
cd=cd.drop("last_review",axis=1)

# %%
cd.isnull().sum()
# Out:
# listing_id                 0
# listing_name               0
# host_id                    0
# host_name                  0
# neighbourhood_group        0
# neighbourhood              0
# latitude                   0
# longitude                  0
# room_type                  0
# price                      0
# minimum_nights             0
# number_of_reviews          0
# total_reviews          10052
# host_listings_count        0
# availability_365           0
# dtype: int64

# %%
cd['total_reviews'] = cd['total_reviews'].fillna(0)

# %%
cd.isnull().sum()
# Out:
# listing_id             0
# listing_name           0
# host_id                0
# host_name              0
# neighbourhood_group    0
# neighbourhood          0
# latitude               0
# longitude              0
# room_type              0
# price                  0
# minimum_nights         0
# number_of_reviews      0
# total_reviews          0
# host_listings_count    0
# availability_365       0
# dtype: int64

# %%
cd.shape
# Out:
# (48895, 15)

# %%
# box plot outliers

# %%
#import matplotlib.pyplot as plt
#import pandas as pd
#import seaborn as sns


#cde = ["listing_id", "host_id", "price", "minimum_nights", "number_of_reviews", "host_listings_count", "availability_365"]
#plt.figure(figsize=(15, 8))
#cd[cde].boxplot()
#plt.title("Box Plots of Numerical Columns")
#plt.ylabel("Values")
#plt.xlabel("Columns")
#plt.xticks(rotation=45)
#plt.tight_layout()
#plt.show()

# %%
col_list=cd.columns

# %%
col_list
# Out:
# Index(['listing_id', 'listing_name', 'host_id', 'host_name',
#        'neighbourhood_group', 'neighbourhood', 'latitude', 'longitude',
#        'room_type', 'price', 'minimum_nights', 'number_of_reviews',
#        'total_reviews', 'host_listings_count', 'availability_365'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

for i in cd.columns:
  if cd[i].dtype !="object":
    sns.boxplot(cd[i])
  plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

sns.histplot(cd["price"],bins=10,color="red",kde=True)
plt.show()

# %%
cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   listing_id           48895 non-null  int64
#  1   listing_name         48895 non-null  object
#  2   host_id              48895 non-null  int64
#  3   host_name            48895 non-null  object
#  4   neighbourhood_group  48895 non-null  object
#  5   neighbourhood        48895 non-null  object
#  6   latitude             48895 non-null  float64
#  7   longitude            48895 non-null  float64
#  8   room_type            48895 non-null  object
#  9   price                48895 non-null  int64
#  10  minimum_nights       48895 non-null  int64
#  11  number_of_reviews    48895 non-null  int64
#  12  total_reviews        48895 non-null  float64
#  13  host_listings_count  48895 non-null  int64
#  14  availability_365     48895 non-null  int64
# ...

# %%
cd["room_type"].value_counts()
# Out:
# room_type
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: count, dtype: int64

# %%
fig=sns.countplot(data=cd,x="room_type", hue="room_type")
for i in fig.containers:
    fig.bar_label(i)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
li=[1,2,3,4,5,6,7,8,12,15,21,20,200,250]
sns.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df=sns.load_dataset("titanic")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
sns.boxplot(y=df["fare"])
# Out:
# <Axes: ylabel='fare'>

# %%
q1=df["fare"].quantile(0.25)
q1
# Out:
# np.float64(7.9104)

# %%
q3=df["fare"].quantile(0.75)
q3
# Out:
# np.float64(31.0)

# %%
iqr=q3-q1
iqr
# Out:
# np.float64(23.0896)

# %%
ub=q3+1.5*iqr
ub
# Out:
# np.float64(65.6344)

# %%
lb=q1-1.5*iqr
lb
# Out:
# np.float64(-26.724)

# %%
df=df[(df["fare"]>=lb) & ]
